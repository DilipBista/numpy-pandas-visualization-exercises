# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("/Users/dilip/Desktop/cust_data - data.csv")
data1
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     1371-DWPAZ  Female                  0     Yes        Yes              0
# 1     2520-SGTTA  Female                  0     Yes        Yes              1
# 2     2775-SEFEE    Male                  0      No        Yes              2
# 3     2923-ARZLG    Male                  0     Yes        Yes              1
# 4     3115-CZMZD    Male                  0      No        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7038  3910-MRQOY  Female                  0     Yes         No              1
# 7039  6010-DDPPW    Male                  0     Yes         No              2
# 7040  7083-MIOPC  Female                  0      No         No              1
# 7041  8207-VVMYB  Female                  0     Yes         No              2
# 7042  5893-KCLGT  Female                  0      No        Yes              1
#
# ...

# %%
data1.shape
# Out:
# (7043, 26)

# %%
data1.head(10)
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  1371-DWPAZ  Female                  0     Yes        Yes              0
# 1  2520-SGTTA  Female                  0     Yes        Yes              1
# 2  2775-SEFEE    Male                  0      No        Yes              2
# 3  2923-ARZLG    Male                  0     Yes        Yes              1
# 4  3115-CZMZD    Male                  0      No        Yes              1
# 5  3213-VVOLG    Male                  0     Yes        Yes              2
# 6  4075-WKNIU  Female                  0     Yes        Yes              2
# 7  4367-NUYAO    Male                  0     Yes        Yes              2
# 8  4472-LVYGI  Female                  0     Yes        Yes              0
# 9  5709-LVOEQ  Female                  0     Yes        Yes              1
#
#    internet_service  contract_type               payment_type monthly_charges  \
# ...

# %%
# relplot seaborn (sns)
sns.relplot(y='customer_id', x = 'is_senior_citizen', data=data1)

# %%
data1.T
# Out:
#                                              0                    1     \
# customer_id                            1371-DWPAZ           2520-SGTTA
# gender                                     Female               Female
# is_senior_citizen                               0                    0
# partner                                       Yes                  Yes
# dependents                                    Yes                  Yes
# phone_service                                   0                    1
# internet_service                                1                    0
# contract_type                                   2                    2
# payment_type              Credit card (automatic)         Mailed check
# monthly_charges                            $56.05               $20.00
# total_charges                                 NaN                  NaN
# churn                                          No                   No
# ...

# %%
pd.crosstab(data1.churn, data1.service_type )
# Out:
# service_type  Internet Only  Phone Only  Phone+Internet
# churn
# No                      512        1413            3249
# Yes                     170         113            1586

# %%
sns.pieplot( x = 'is_senior_citizen', data=data1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-0f1aedc55707> in <module>
# ----> 1 sns.pieplot( x = 'is_senior_citizen', data=data1)
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'

# %%
pd.crosstab(data1.churn, data1.is_senior_citizen )
# Out:
# is_senior_citizen     0    1
# churn
# No                 4508  666
# Yes                1393  476

# %%
pd.crosstab(data1.churn, data1.gender )
# Out:
# gender  Female  Male
# churn
# No        2549  2625
# Yes        939   930

# %%
pd.crosstab(data1.churn, data1.dependents)
# Out:
# dependents    No   Yes
# churn
# No          3390  1784
# Yes         1543   326

# %%
pd.crosstab(data1.service_type, data1.gender)
# Out:
# gender          Female  Male
# service_type
# Internet Only      331   351
# Phone Only         747   779
# Phone+Internet    2410  2425

# %%
pd.crosstab(data1.service_type, data1.churn)
# Out:
# churn             No   Yes
# service_type
# Internet Only    512   170
# Phone Only      1413   113
# Phone+Internet  3249  1586

# %%
pd.crosstab(data1.service_type, data1.contract_type)
# Out:
# contract_type      0    1    2
# service_type
# Internet Only    376  145  161
# Phone Only       524  364  638
# Phone+Internet  2975  964  896

# %%
pd.crosstab(data1.service_type, data1.payment_type)
# Out:
# payment_type    Bank transfer (automatic)  Credit card (automatic)  \
# service_type
# Internet Only                         143                      154
# Phone Only                            332                      331
# Phone+Internet                       1069                     1037
#
# payment_type    Electronic check  Mailed check
# service_type
# Internet Only                226           159
# Phone Only                   122           741
# Phone+Internet              2017           712

# %%
pd.crosstab(data1.service_type, data1.average_monthly_charges)
# Out:
# average_monthly_charges  $0.00  $100.00  $100.05  $100.10  $100.15  $100.20  \
# service_type
# Internet Only                2        0        0        0        0        0
# Phone Only                   6        0        0        0        0        0
# Phone+Internet               3        6       10        2        8        8
#
# average_monthly_charges  $100.25  $100.30  $100.35  $100.40  ...  $99.50  \
# service_type                                                 ...
# Internet Only                  0        0        0        0  ...       0
# Phone Only                     0        0        0        0  ...       0
# Phone+Internet                 6        9        3        5  ...      10
#
# average_monthly_charges  $99.55  $99.60  $99.65  $99.70  $99.75  $99.80  \
# service_type
# Internet Only                 0       0       0       0       0       0
# Phone Only                    0       0       0       0       0       0
# ...

# %%
pd.crosstab(data1.service_type, data1.monthly_charges)
# Out:
# monthly_charges  $100.00  $100.05  $100.10  $100.15  $100.20  $100.25  \
# service_type
# Internet Only          0        0        0        0        0        0
# Phone Only             0        0        0        0        0        0
# Phone+Internet         6       10        2        8        8        6
#
# monthly_charges  $100.30  $100.35  $100.40  $100.45  ...  $99.50  $99.55  \
# service_type                                         ...
# Internet Only          0        0        0        0  ...       0       0
# Phone Only             0        0        0        0  ...       0       0
# Phone+Internet         9        3        5        6  ...      10       4
#
# monthly_charges  $99.60  $99.65  $99.70  $99.75  $99.80  $99.85  $99.90  \
# service_type
# Internet Only         0       0       0       0       0       0       0
# Phone Only            0       0       0       0       0       0       0
# Phone+Internet        1       9       7       4       7       5       4
#
# ...
